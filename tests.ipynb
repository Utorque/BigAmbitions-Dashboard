# %%
import pandas as pd

# %%
CATEGORIES = {
    "expenses_categories": {
        "Rent": ["rent"],
        "Marketing": ["marketing"],
        "Training": ["training", "hr training"],
        "Daily Wage": ["daily wage", "wage"],
        "Vehicle": ["vehicle"],
        "Delivery": ["delivery"],
        "Purchase": ["purchase"],
        "Import": ["import"],
        "Moving": ["moving"],
        "Recruitment": ["recruitment"],
        "Deposit": ["deposit"]
    },
    "companies": {
        "Best Websites Ever": ["best websites ever"],
        "Best Jewelery": ["best jewelery"],
        "Luxury Clothes": ["luxury clothes"],
        "Best Inc": ["best inc"]
    }
}

def load_and_process_data(csv_path):
    # Read CSV file
    df = pd.read_csv(csv_path, 
                    names=['Description', 'Day', 'Type', 'Amount', 'ID'],
                    quotechar='"',
                    encoding='utf-8')
    
    # Clean any potential whitespace
    df = df.apply(lambda x: x.str.strip() if isinstance(x, str) else x)
    
    # Convert numeric columns
    df['Day'] = pd.to_numeric(df['Day'])
    df['Amount'] = pd.to_numeric(df['Amount'])
    
    # Add calculated columns
    df['is_expense'] = df['Amount'] < 0
    df['abs_amount'] = df['Amount'].abs()
    
    # Add category columns
    df['expense_category'] = 'Other'
    df['company'] = 'Other'
    
    # Categorize expenses
    for category, keywords in CATEGORIES['expenses_categories'].items():
        mask = df['Description'].str.lower().str.contains('|'.join(keywords), case=False)
        df.loc[mask, 'expense_category'] = category
    
    # Categorize companies
    for company, keywords in CATEGORIES['companies'].items():
        mask = df['Description'].str.lower().str.contains('|'.join(keywords), case=False)
        df.loc[mask, 'company'] = company
    
    return df

# %%
df = load_and_process_data(r"C:\Users\Thibault\AppData\LocalLow\Hovgaard Games\Big Ambitions\SaveGames\EA 0.6\7BT1vEwZVEGXpXoAL250wQ==\Transactions.csv")

# %%
df.head()
# Out:
#                                   Description  Day       Type  Amount     ID  \
# 0      Marketing campaigns for Luxury Clothes   69  Marketing  -500.0  18201
# 1  Marketing campaigns for Best Websites Ever   69  Marketing -2500.0  18701
# 2       Marketing campaigns for Best Jewelery   69  Marketing  -500.0  21201
# 3                           6 5th Avenue Rent   69       Rent   -25.0  16521
# 4                          51 2nd Street Rent   69       Rent   -55.0  16546
#
#    is_expense  abs_amount expense_category             company
# 0        True       500.0        Marketing      Luxury Clothes
# 1        True      2500.0        Marketing  Best Websites Ever
# 2        True       500.0        Marketing       Best Jewelery
# 3        True        25.0             Rent               Other
# 4        True        55.0             Rent               Other

# %%
income_expense_df = df.loc[:,["is_expense","Type","Amount"]]

# %%
# %pip install nbformat>=4.2.0
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
px.bar(income_expense_df, x="Type", y="Amount", color="is_expense", barmode="group", title="Income and Expenses by Type")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\Thibault\Documents\BigCompany Analysis\venv\Lib\site-packages\IPython\core\formatters.py:925, in IPythonDisplayFormatter.__call__(self, obj)
#     923 method = get_real_method(obj, self.print_method)
#     924 if method is not None:
# --> 925     method()
#     926     return True
#
# File c:\Users\Thibault\Documents\BigCompany Analysis\venv\Lib\site-packages\plotly\basedatatypes.py:832, in BaseFigure._ipython_display_(self)
#     829 import plotly.io as pio
#     831 if pio.renderers.render_on_display and pio.renderers.default:
# --> 832     pio.show(self)
#     833 else:
#     834     print(repr(self))
#
# File c:\Users\Thibault\Documents\BigCompany Analysis\venv\Lib\site-packages\plotly\io\_renderers.py:394, in show(fig, renderer, validate, **kwargs)
#     389         raise ValueError(
#     390             "Mime type rendering requires ipython but it is not installed"
#     391         )
#     393     if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 394         raise ValueError(
#     395             "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     396         )
#     398     ipython_display.display(bundle, raw=True)
#     400 # external renderers
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
# Figure({
#     'data': [{'alignmentgroup': 'True',
#               'hovertemplate': 'is_expense=True<br>Type=%{x}<br>Amount=%{y}<extra></extra>',
#               'legendgroup': 'True',
#               'marker': {'color': '#636efa', 'pattern': {'shape': ''}},
#               'name': 'True',
#               'offsetgroup': 'True',
#               'orientation': 'v',
#               'showlegend': True,
#               'textposition': 'auto',
#               'type': 'bar',
#               'x': array(['Marketing', 'Marketing', 'Marketing', ..., 'Marketing', 'Marketing',
#                           'Rent'], dtype=object),
#               'xaxis': 'x',
#               'y': array([ -500., -2500.,  -500., ...,  -100.,  -500.,   -25.]),
#               'yaxis': 'y'},
#              {'alignmentgroup': 'True',
#               'hovertemplate': 'is_expense=False<br>Type=%{x}<br>Amount=%{y}<extra></extra>',
#               'legendgroup': 'False',
#               'marker': {'color': '#EF553B', 'pattern': {'shape': ''}},
#               'name': 'False',
#               'offsetgroup': 'False',
#               'orientation': 'v',
#               'showlegend': True,
#               'textposition': 'auto',
#               'type': 'bar',
#               'x': array(['Revenue', 'Revenue', 'Revenue', 'Revenue', 'Revenue', 'Revenue',
#                           'Revenue', 'Revenue', 'Revenue', 'Revenue', 'Revenue', 'Revenue',
#                           'Revenue', 'Revenue', 'Revenue', 'Revenue', 'Item Sold', 'Revenue',
#                           'Revenue', 'Revenue', 'Revenue', 'Revenue', 'Revenue', 'Revenue',
#                           'Revenue', 'Revenue', 'Revenue', 'Revenue', 'Revenue', 'Revenue',
#                           'Import Delivery Refund', 'Revenue', 'Revenue', 'Revenue', 'Revenue',
#                           'Revenue', 'Revenue', 'Revenue', 'Revenue', 'Revenue', 'Revenue',
#                           'Revenue', 'Revenue', 'Revenue', 'Revenue', 'Revenue', 'Revenue',
#                           'Revenue', 'Revenue', 'Revenue', 'Revenue', 'Revenue', 'Revenue',
#                           'Revenue', 'Revenue', 'Revenue', 'Revenue', 'Revenue', 'Revenue',
#                           'Revenue', 'Revenue', 'Revenue', 'Revenue', 'Revenue', 'Revenue',
#                           'Revenue', 'Revenue', 'Revenue', 'Revenue', 'Revenue', 'Revenue',
#                           'Revenue', 'Revenue', 'Revenue', 'Revenue', 'Revenue', 'Revenue',
#                           'Revenue', 'Revenue', 'Revenue', 'Revenue', 'Revenue', 'Revenue',
#                           'Revenue', 'Revenue', 'Revenue', 'Revenue', 'Revenue', 'Revenue',
#                           'Revenue', 'Revenue', 'Revenue', 'Revenue', 'Revenue', 'Revenue',
#                           'Revenue', 'Revenue', 'Revenue', 'Revenue', 'Revenue'], dtype=object),
#               'xaxis': 'x',
#               'y': array([ 5180.   ,  9858.   ,   200.   ,  5740.   ,  4871.2  ,   800.   ,
#                            2835.8  ,  5600.   ,   400.   ,  7476.2  ,  5180.   ,   200.   ,
#                            7734.   ,  5320.   ,  1200.   ,  7734.   ,   750.   ,  5880.   ,
#                           10000.   ,  5600.   , 10000.   ,  6160.   , 10000.   ,  5542.7  ,
#                            5460.   ,  7600.   ,  5952.4  ,  5320.   ,  7000.   ,  6858.2  ,
#                            6319.098,  5180.   ,  7800.   ,  6858.2  ,  5180.   ,  2600.   ,
#                            5952.4  ,  5740.   ,  8800.   ,  4200.   ,  8400.   ,  3080.   ,
#                            9600.   ,  5046.6  ,  4800.   ,  6858.2  ,   400.   ,  6800.   ,
#                            6599.4  ,   400.   ,  7400.   ,  7634.6  ,  1850.   ,  6200.   ,
#                            8411.   ,  1200.   ,  3600.   ,   400.   ,  9600.   ,   800.   ,
#                            9446.199,   650.   ,  6200.   ,  9705.   ,  7600.   ,  9963.8  ,
#                            3710.   ,  6000.   ,  9446.199,  2226.   ,  2400.   ,  9834.399,
#                            3710.   ,  6880.   ,  3710.   ,  7200.   ,  1416.8  ,  3710.   ,
#                            6400.   ,  7728.   ,  4452.   ,  7728.   ,  3710.   ,  7728.   ,
#                            3710.   ,  7728.   ,  3710.   ,  7728.7  ,  3710.   ,  1417.9  ,
#                            3710.   ,  1417.9  ,  3710.   ,  3222.5  ,  3710.   ,  3222.5  ,
#                            3964.   ,  3222.5  ,  2958.   ,  3222.5  ]),
#               'yaxis': 'y'}],
#     'layout': {'barmode': 'group',
#                'legend': {'title': {'text': 'is_expense'}, 'tracegroupgap': 0},
#                'template': '...',
#                'title': {'text': 'Income and Expenses by Type'},
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'title': {'text': 'Type'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'title': {'text': 'Amount'}}}
# })

# %%
income_df = df[df['Amount'] > 0].groupby('Type')['Amount'].sum()
expense_df = df[df['Amount'] < 0].groupby('Type')['abs_amount'].sum()

# %%
income_df.head()
# Out:
# Type
# Import Delivery Refund      6319.098
# Item Sold                    750.000
# Revenue                   515011.797
# Name: Amount, dtype: float64

# %%
import plotly.express as px
long_df = px.data.medals_long()
long_df.head()
# Out:
#         nation   medal  count
# 0  South Korea    gold     24
# 1        China    gold     10
# 2       Canada    gold      9
# 3  South Korea  silver     13
# 4        China  silver     15
